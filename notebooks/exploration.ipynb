# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"C:\Users\asus\Desktop\crop-recommender\data\Crop_recommendation.csv")

print("✅ Dataset loaded!")
print(f"Shape: {df.shape}")
# Out:
# ✅ Dataset loaded!
# Shape: (2200, 8)

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
print("Missing values per column:")
print(df.isnull().sum())

print(f"\nTotal missing values: {df.isnull().sum().sum()}")
# Out:
# Missing values per column:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64
#
# Total missing values: 0

# %%
print(f"Number of unique crops: {df['label'].nunique()}")
print("\nCrop distribution:")
print(df['label'].value_counts())
# Out:
# Number of unique crops: 22
#
# Crop distribution:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df.describe().round(2)
# Out:
#              N        P        K  temperature  humidity       ph  rainfall
# count  2200.00  2200.00  2200.00      2200.00   2200.00  2200.00   2200.00
# mean     50.55    53.36    48.15        25.62     71.48     6.47    103.46
# std      36.92    32.99    50.65         5.06     22.26     0.77     54.96
# min       0.00     5.00     5.00         8.83     14.26     3.50     20.21
# 25%      21.00    28.00    20.00        22.77     60.26     5.97     64.55
# 50%      37.00    51.00    32.00        25.60     80.47     6.43     94.87
# 75%      84.25    68.00    49.00        28.56     89.95     6.92    124.27
# max     140.00   145.00   205.00        43.68     99.98     9.94    298.56

# %%
plt.figure(figsize=(14, 5))
df['label'].value_counts().plot(kind='bar', color='steelblue', edgecolor='black')
plt.title("Number of Samples per Crop", fontsize=14)
plt.xlabel("Crop")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("../data/crop_distribution.png")  
plt.show()

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

df[features].hist(bins=20, figsize=(14, 8), color='teal', edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=14)
plt.tight_layout()
plt.savefig("../data/feature_distributions.png")
plt.show()

# %%
plt.figure(figsize=(9, 6))
sns.heatmap(df[features].corr(), annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Feature Correlation Heatmap", fontsize=14)
plt.tight_layout()
plt.savefig("../data/correlation_heatmap.png")
plt.show()

# %%
plt.figure(figsize=(14, 5))
sns.boxplot(data=df, x='label', y='rainfall', palette='Set2')
plt.title("Rainfall Requirements by Crop", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("../data/rainfall_by_crop.png")
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_17280\1248088077.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='label', y='rainfall', palette='Set2')
